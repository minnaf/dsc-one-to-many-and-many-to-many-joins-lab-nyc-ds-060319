# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
#Your code here
import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %%
c.execute('SELECT * FROM employees')

employees = [description[0] for description in c.description]

# %%
# Out:
# ['employeeNumber',
#  'lastName',
#  'firstName',
#  'extension',
#  'email',
#  'officeCode',
#  'reportsTo',
#  'jobTitle']

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here

c.execute('''SELECT firstName, lastName, city, state FROM employees JOIN offices
                USING(officeCode) ORDER BY firstName, lastName''')
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    firstName   lastName           city       state
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# 19     Steve  Patterson         Boston          MA
# 20       Tom       King         Sydney
# 21   William  Patterson         Sydney
# 22   Yoshimi       Kato          Tokyo  Chiyoda-Ku

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
# Your code here


c.execute('''SELECT customerName, contactLastName, contactFirstName,
             orderNumber, orderDate, status FROM customers JOIN orders
             USING(customerNumber) ORDER BY contactLastName''')


df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#                      customerName contactLastName contactFirstName  \
# 0              Amica Models & Co.         Accorti           Paolo
# 1              Amica Models & Co.         Accorti           Paolo
# 2                  AV Stores, Co.        Ashworth           Rachel
# 3                  AV Stores, Co.        Ashworth           Rachel
# 4                  AV Stores, Co.        Ashworth           Rachel
# 5        Online Mini Collectables         Barajas           Miguel
# 6        Online Mini Collectables         Barajas           Miguel
# 7                FunGiftIdeas.com         Benitez          Violeta
# 8                FunGiftIdeas.com         Benitez          Violeta
# 9                FunGiftIdeas.com         Benitez          Violeta
# 10              giftsbymail.co.uk         Bennett           Helen
# 11              giftsbymail.co.uk         Bennett           Helen
# 12       Volvo Model Replicas, Co        Berglund       Christina
# 13       Volvo Model Replicas, Co        Berglund       Christina
# 14       Volvo Model Replicas, Co        Berglund       Christina
# 15       Volvo Model Replicas, Co        Berglund       Christina
# 16             Baane Mini Imports      Bergulfsen           Jonas
# 17             Baane Mini Imports      Bergulfsen           Jonas
# 18             Baane Mini Imports      Bergulfsen           Jonas
# 19             Baane Mini Imports      Bergulfsen           Jonas
# 20      La Corne D'abondance, Co.        Bertrand            Marie
# 21      La Corne D'abondance, Co.        Bertrand            Marie
# 22      La Corne D'abondance, Co.        Bertrand            Marie
# 23       Corporate Gift Ideas Co.           Brown            Julie
# 24       Corporate Gift Ideas Co.           Brown            Julie
# 25       Corporate Gift Ideas Co.           Brown            Julie
# 26       Corporate Gift Ideas Co.           Brown            Julie
# 27       Stylish Desk Decors, Co.           Brown             Ann
# 28       Stylish Desk Decors, Co.           Brown             Ann
# 29       Stylish Desk Decors, Co.           Brown             Ann
# ..                            ...             ...              ...
# 296       Auto-Moto Classics Inc.          Taylor           Leslie
# 297      Signal Collectibles Ltd.          Taylor              Sue
# 298      Signal Collectibles Ltd.          Taylor              Sue
# 299  Collectable Mini Designs Co.        Thompson          Valarie
# 300  Collectable Mini Designs Co.        Thompson          Valarie
# 301   West Coast Collectables Co.        Thompson            Steve
# 302   West Coast Collectables Co.        Thompson            Steve
# 303          Auto Associés & Cie.          Tonini          Daniel
# 304          Auto Associés & Cie.          Tonini          Daniel
# 305    Cambridge Collectables Co.           Tseng            Jerry
# 306    Cambridge Collectables Co.           Tseng            Jerry
# 307              Handji Gifts& Co       Victorino            Wendy
# 308              Handji Gifts& Co       Victorino            Wendy
# 309              Handji Gifts& Co       Victorino            Wendy
# 310              Handji Gifts& Co       Victorino            Wendy
# 311             Gifts4AllAges.com         Yoshido             Juri
# 312             Gifts4AllAges.com         Yoshido             Juri
# 313             Gifts4AllAges.com         Yoshido             Juri
# 314            Muscle Machine Inc           Young             Jeff
# 315            Muscle Machine Inc           Young             Jeff
# 316            Muscle Machine Inc           Young             Jeff
# 317            Muscle Machine Inc           Young             Jeff
# 318             Toys4GrownUps.com           Young            Julie
# 319             Toys4GrownUps.com           Young            Julie
# 320             Toys4GrownUps.com           Young            Julie
# 321             Boards & Toys Co.           Young             Mary
# 322             Boards & Toys Co.           Young             Mary
# 323  Online Diecast Creations Co.           Young          Dorothy
# 324  Online Diecast Creations Co.           Young          Dorothy
# 325  Online Diecast Creations Co.           Young          Dorothy
#
#     orderNumber   orderDate    status
# 0         10280  2004-08-17   Shipped
# 1         10293  2004-09-09   Shipped
# 2         10110  2003-03-18   Shipped
# 3         10306  2004-10-14   Shipped
# 4         10332  2004-11-17   Shipped
# 5         10276  2004-08-02   Shipped
# 6         10294  2004-09-10   Shipped
# 7         10166  2003-10-21   Shipped
# 8         10321  2004-11-04   Shipped
# 9         10388  2005-03-03   Shipped
# 10        10232  2004-03-20   Shipped
# 11        10316  2004-11-01   Shipped
# 12        10112  2003-03-24   Shipped
# 13        10320  2004-11-03   Shipped
# 14        10326  2004-11-09   Shipped
# 15        10334  2004-11-19   On Hold
# 16        10103  2003-01-29   Shipped
# 17        10158  2003-10-10   Shipped
# 18        10309  2004-10-15   Shipped
# 19        10325  2004-11-05   Shipped
# 20        10114  2003-04-01   Shipped
# 21        10286  2004-08-28   Shipped
# 22        10336  2004-11-20   Shipped
# 23        10159  2003-10-10   Shipped
# 24        10162  2003-10-18   Shipped
# 25        10381  2005-02-17   Shipped
# 26        10384  2005-02-23   Shipped
# 27        10129  2003-06-12   Shipped
# 28        10175  2003-11-06   Shipped
# 29        10351  2004-12-03   Shipped
# ..          ...         ...       ...
# 296       10352  2004-12-03   Shipped
# 297       10149  2003-09-12   Shipped
# 298       10219  2004-02-10   Shipped
# 299       10222  2004-02-19   Shipped
# 300       10226  2004-02-26   Shipped
# 301       10199  2003-12-01   Shipped
# 302       10215  2004-01-29   Shipped
# 303       10216  2004-02-02   Shipped
# 304       10304  2004-10-11   Shipped
# 305       10228  2004-03-10   Shipped
# 306       10249  2004-05-08   Shipped
# 307       10217  2004-02-04   Shipped
# 308       10259  2004-06-15   Shipped
# 309       10288  2004-09-01   Shipped
# 310       10409  2005-04-23   Shipped
# 311       10264  2004-06-30   Shipped
# 312       10295  2004-09-10   Shipped
# 313       10414  2005-05-06   On Hold
# 314       10127  2003-06-03   Shipped
# 315       10204  2003-12-02   Shipped
# 316       10267  2004-07-07   Shipped
# 317       10349  2004-12-01   Shipped
# 318       10145  2003-08-25   Shipped
# 319       10189  2003-11-18   Shipped
# 320       10367  2005-01-12  Resolved
# 321       10154  2003-10-02   Shipped
# 322       10376  2005-02-08   Shipped
# 323       10100  2003-01-06   Shipped
# 324       10192  2003-11-20   Shipped
# 325       10322  2004-11-04   Shipped
#
# [326 rows x 6 columns]

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here
c.execute('''SELECT contactLastName, contactFirstName,
             paymentDate, amount FROM customers JOIN payments
             USING(customerNumber) ORDER BY amount DESC;''')

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     contactLastName contactFirstName paymentDate     amount
# 0           Benitez          Violeta  2003-11-08    9977.85
# 1          Calaghan              Ben  2003-10-17    9821.32
# 2            Taylor           Leslie  2004-12-06    9658.74
# 3          Clenahan             Sean  2004-07-28    9415.13
# 4            Mendel          Roland   2005-05-03    8807.12
# 5             Brown            Julie  2003-11-03   85559.12
# 6            Nelson            Susan  2004-08-28   85410.87
# 7            Oeztan           Veysel  2003-12-03   85024.46
# 8            Nelson            Susan  2005-04-16   83598.04
# 9             Huang             Wing  2005-01-18    8307.28
# 10         Ferguson            Peter  2004-12-15   82261.22
# 11         Thompson          Valarie  2004-03-15   80375.24
# 12         Thompson            Steve  2003-12-09    7678.25
# 13         Berglund       Christina   2003-04-09    7674.94
# 14          Ricotti           Franco  2004-02-17    7612.06
# 15         Ferguson            Peter  2003-05-31    7565.08
# 16           Graham             Mike  2005-05-23   75020.13
# 17           Keitel           Roland  2004-11-18    7466.32
# 18            Smith          Thomas   2004-01-31    7310.42
# 19            Brown          William  2004-04-16    7178.66
# 20            Lewis              Dan  2003-09-15    6631.36
# 21           Freyre           Diego   2005-03-25   65071.26
# 22            Pipps           Georg   2004-08-01    6419.84
# 23           Freyre           Diego   2003-12-09   63843.55
# 24            Leong           Kelvin  2004-09-07   63357.13
# 25           Franco          Valarie  2004-05-14    6276.60
# 26        Shimamura            Akiko  2005-05-18     615.45
# 27             Holz           Mihael  2004-09-18   61402.00
# 28        Pfalzheim       Henriette   2004-11-06   61234.67
# 29          Schmitt          Carine   2004-10-19    6066.78
# ..              ...              ...         ...        ...
# 243       Koskitalo           Pirkko  2004-04-25   16212.59
# 244            Cruz           Arnold  2004-11-19   15822.84
# 245       Fernandez            Jesus  2004-04-02   15322.93
# 246         Kentary             Mory  2004-04-17   15183.63
# 247          Mendel          Roland   2003-11-20   15130.97
# 248         Yoshido             Juri  2004-09-21   15059.76
# 249      Bergulfsen           Jonas   2003-10-28    1491.38
# 250         Schmitt          Carine   2003-06-05   14571.44
# 251        Cartrain         Pascale   2005-02-03   14379.90
# 252          Roulet         Annette   2003-07-21   14232.70
# 253            King             Jean  2004-12-17   14191.12
# 254         Henriot            Paul   2003-07-21   13920.26
# 255           Brown             Ann   2004-12-13   13671.82
# 256       Hashimoto             Juri  2005-02-02   12692.19
# 257          Taylor              Sue  2004-02-29   12573.28
# 258          Oeztan           Veysel  2004-09-19   12538.01
# 259          Nelson            Allen  2004-08-02   12530.51
# 260          Roulet         Annette   2005-06-03   12432.32
# 261         Perrier        Dominique  2005-04-23   12190.85
# 262        Cartrain         Pascale   2004-12-03   12081.52
# 263          Freyre           Diego   2005-03-18  120166.58
# 264           Tseng            Jerry  2004-05-13   11843.45
# 265          Freyre           Diego   2004-12-31  116208.40
# 266        Cartrain         Pascale   2003-08-22    1128.20
# 267          Nelson            Susan  2003-08-15  111654.40
# 268          Nelson            Susan  2003-04-11   11044.30
# 269       Natividad             Eric  2003-12-26  105743.00
# 270          Keitel           Roland  2003-01-28   10549.01
# 271           Young          Dorothy  2003-01-16   10223.83
# 272          Nelson            Susan  2005-03-05  101244.59
#
# [273 rows x 4 columns]

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here
c.execute('''SELECT contactLastName, contactFirstName, productName,
             quantityOrdered, orderDate FROM employees JOIN ''')

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
