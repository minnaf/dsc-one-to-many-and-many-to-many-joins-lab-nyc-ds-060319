# %% [markdown]
# # One-to-Many and Many-to-Many Joins - Lab

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you'll practice your knowledge on one-to-many and many-to-many relationships!

# %% [markdown]
# ## Objectives

# %% [markdown]
# You will be able to:
# - Query data using one-to-many and many-to-many joins
# - Predict the resulting size of one-to-many and many-to-many joins

# %% [markdown]
# ## One-to-Many and Many-to-Many Joins
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connect to the Database

# %%
#Your code here
import pandas as pd
import sqlite3

conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %%
c.execute('SELECT * FROM employees')

employees = [description[0] for description in c.description]

# %%
# Out:
# ['employeeNumber',
#  'lastName',
#  'firstName',
#  'extension',
#  'email',
#  'officeCode',
#  'reportsTo',
#  'jobTitle']

# %% [markdown]
# ## Employees and their Office (a One-to-One join)
#
# Return a list of all of the employees with their first name, last name and the city and state of the office that they work out of (if they have one). Include all employees and order them by their first name, then their last name.

# %%
#Your code here

c.execute('''SELECT firstName, lastName, city, state FROM employees JOIN offices
                USING(officeCode) ORDER BY firstName, lastName''')
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#    firstName   lastName           city       state
# 0       Andy     Fixter         Sydney
# 1    Anthony        Bow  San Francisco          CA
# 2      Barry      Jones         London
# 3      Diane     Murphy  San Francisco          CA
# 4   Foon Yue      Tseng            NYC          NY
# 5     George     Vanauf            NYC          NY
# 6     Gerard     Bondur          Paris
# 7     Gerard  Hernandez          Paris
# 8       Jeff   Firrelli  San Francisco          CA
# 9      Julie   Firrelli         Boston          MA
# 10     Larry       Bott         London
# 11    Leslie   Jennings  San Francisco          CA
# 12    Leslie   Thompson  San Francisco          CA
# 13      Loui     Bondur          Paris
# 14      Mami      Nishi          Tokyo  Chiyoda-Ku
# 15    Martin     Gerard          Paris
# 16      Mary  Patterson  San Francisco          CA
# 17    Pamela   Castillo          Paris
# 18     Peter      Marsh         Sydney
# 19     Steve  Patterson         Boston          MA
# 20       Tom       King         Sydney
# 21   William  Patterson         Sydney
# 22   Yoshimi       Kato          Tokyo  Chiyoda-Ku

# %% [markdown]
# ## Customers and their Orders (a One-to-Many join)
#
# Return a list of all the customers first and last names along with a record for each of their order numbers, order dates and statuses.

# %%
# Your code here


c.execute('''SELECT customerName, contactLastName, contactFirstName,
             orderNumber, orderDate, status FROM customers JOIN orders
             USING(customerNumber) ORDER BY ''')

df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#                        customerName contactLastName contactFirstName  \
# 0                 Atelier graphique         Schmitt          Carine
# 1                 Atelier graphique         Schmitt          Carine
# 2                 Atelier graphique         Schmitt          Carine
# 3                Signal Gift Stores            King             Jean
# 4                Signal Gift Stores            King             Jean
# 5                Signal Gift Stores            King             Jean
# 6        Australian Collectors, Co.        Ferguson            Peter
# 7        Australian Collectors, Co.        Ferguson            Peter
# 8        Australian Collectors, Co.        Ferguson            Peter
# 9        Australian Collectors, Co.        Ferguson            Peter
# 10       Australian Collectors, Co.        Ferguson            Peter
# 11                La Rochelle Gifts         Labrune          Janine
# 12                La Rochelle Gifts         Labrune          Janine
# 13                La Rochelle Gifts         Labrune          Janine
# 14                La Rochelle Gifts         Labrune          Janine
# 15               Baane Mini Imports      Bergulfsen           Jonas
# 16               Baane Mini Imports      Bergulfsen           Jonas
# 17               Baane Mini Imports      Bergulfsen           Jonas
# 18               Baane Mini Imports      Bergulfsen           Jonas
# 19     Mini Gifts Distributors Ltd.          Nelson            Susan
# 20     Mini Gifts Distributors Ltd.          Nelson            Susan
# 21     Mini Gifts Distributors Ltd.          Nelson            Susan
# 22     Mini Gifts Distributors Ltd.          Nelson            Susan
# 23     Mini Gifts Distributors Ltd.          Nelson            Susan
# 24     Mini Gifts Distributors Ltd.          Nelson            Susan
# 25     Mini Gifts Distributors Ltd.          Nelson            Susan
# 26     Mini Gifts Distributors Ltd.          Nelson            Susan
# 27     Mini Gifts Distributors Ltd.          Nelson            Susan
# 28     Mini Gifts Distributors Ltd.          Nelson            Susan
# 29     Mini Gifts Distributors Ltd.          Nelson            Susan
# ..                              ...             ...              ...
# 296                 Microscale Inc.            Choi               Yu
# 297                 Microscale Inc.            Choi               Yu
# 298      Corrida Auto Replicas, Ltd          Sommer          Martín
# 299      Corrida Auto Replicas, Ltd          Sommer          Martín
# 300      Corrida Auto Replicas, Ltd          Sommer          Martín
# 301                FunGiftIdeas.com         Benitez          Violeta
# 302                FunGiftIdeas.com         Benitez          Violeta
# 303                FunGiftIdeas.com         Benitez          Violeta
# 304    Australian Collectables, Ltd        Clenahan             Sean
# 305    Australian Collectables, Ltd        Clenahan             Sean
# 306    Australian Collectables, Ltd        Clenahan             Sean
# 307              Frau da Collezione         Ricotti           Franco
# 308              Frau da Collezione         Ricotti           Franco
# 309     West Coast Collectables Co.        Thompson            Steve
# 310     West Coast Collectables Co.        Thompson            Steve
# 311      Iberia Gift Imports, Corp.            Roel      José Pedro
# 312      Iberia Gift Imports, Corp.            Roel      José Pedro
# 313    Motor Mint Distributors Inc.         Salazar             Rosa
# 314    Motor Mint Distributors Inc.         Salazar             Rosa
# 315    Motor Mint Distributors Inc.         Salazar             Rosa
# 316        Signal Collectibles Ltd.          Taylor              Sue
# 317        Signal Collectibles Ltd.          Taylor              Sue
# 318  Double Decker Gift Stores, Ltd           Smith          Thomas
# 319  Double Decker Gift Stores, Ltd           Smith          Thomas
# 320            Diecast Collectables          Franco          Valarie
# 321            Diecast Collectables          Franco          Valarie
# 322               Kelly's Gift Shop         Snowden             Tony
# 323               Kelly's Gift Shop         Snowden             Tony
# 324               Kelly's Gift Shop         Snowden             Tony
# 325               Kelly's Gift Shop         Snowden             Tony
#
#     orderNumber   orderDate      status
# 0         10123  2003-05-20     Shipped
# 1         10298  2004-09-27     Shipped
# 2         10345  2004-11-25     Shipped
# 3         10124  2003-05-21     Shipped
# 4         10278  2004-08-06     Shipped
# 5         10346  2004-11-29     Shipped
# 6         10120  2003-04-29     Shipped
# 7         10125  2003-05-21     Shipped
# 8         10223  2004-02-20     Shipped
# 9         10342  2004-11-24     Shipped
# 10        10347  2004-11-29     Shipped
# 11        10275  2004-07-23     Shipped
# 12        10315  2004-10-29     Shipped
# 13        10375  2005-02-03     Shipped
# 14        10425  2005-05-31  In Process
# 15        10103  2003-01-29     Shipped
# 16        10158  2003-10-10     Shipped
# 17        10309  2004-10-15     Shipped
# 18        10325  2004-11-05     Shipped
# 19        10113  2003-03-26     Shipped
# 20        10135  2003-07-02     Shipped
# 21        10142  2003-08-08     Shipped
# 22        10182  2003-11-12     Shipped
# 23        10229  2004-03-11     Shipped
# 24        10271  2004-07-20     Shipped
# 25        10282  2004-08-20     Shipped
# 26        10312  2004-10-21     Shipped
# 27        10335  2004-11-19     Shipped
# 28        10357  2004-12-10     Shipped
# 29        10368  2005-01-19     Shipped
# ..          ...         ...         ...
# 296       10242  2004-04-20     Shipped
# 297       10319  2004-11-03     Shipped
# 298       10126  2003-05-28     Shipped
# 299       10214  2004-01-26     Shipped
# 300       10348  2004-11-01     Shipped
# 301       10166  2003-10-21     Shipped
# 302       10321  2004-11-04     Shipped
# 303       10388  2005-03-03     Shipped
# 304       10193  2003-11-21     Shipped
# 305       10265  2004-07-02     Shipped
# 306       10415  2005-05-09    Disputed
# 307       10157  2003-10-09     Shipped
# 308       10218  2004-02-09     Shipped
# 309       10199  2003-12-01     Shipped
# 310       10215  2004-01-29     Shipped
# 311       10184  2003-11-14     Shipped
# 312       10303  2004-10-06     Shipped
# 313       10109  2003-03-10     Shipped
# 314       10236  2004-04-03     Shipped
# 315       10331  2004-11-17     Shipped
# 316       10149  2003-09-12     Shipped
# 317       10219  2004-02-10     Shipped
# 318       10186  2003-11-14     Shipped
# 319       10213  2004-01-22     Shipped
# 320       10207  2003-12-09     Shipped
# 321       10243  2004-04-26     Shipped
# 322       10138  2003-07-07     Shipped
# 323       10179  2003-11-11   Cancelled
# 324       10360  2004-12-16     Shipped
# 325       10399  2005-04-01     Shipped
#
# [326 rows x 6 columns]

# %% [markdown]
# ## Customers and their Payments (another One-to-Many join)
#
# Return a list of customers first and last names along with details about their payments including the amount and date of payments. Sort these results in descending order by the payment amount.

# %%
# Your code here

# %% [markdown]
# ## Orders, Order details and Product Details (a Many-to-Many Join)

# %% [markdown]
# Return a list of customer first and last names, product names, quantities, and date ordered for each of the customers and each of their orders. Sort these in descending order by the order date.
#
# Note: This will require joining 4 tables! This can be tricky! Give it a shot, and if you're still stuck, turn to the next section where you'll see how to write subqueries which can make complex queries such as this much simpler!

# %%
# Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# In this lab, you practiced your knowledge on one-to-many and many-to-many relationships!
